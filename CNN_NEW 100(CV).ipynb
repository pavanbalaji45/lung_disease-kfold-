# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization
from tensorflow.keras import models,layers
from tensorflow.keras.optimizers import RMSprop  # Import the legacy RMSprop optimizer
from tensorflow.keras.utils import to_categorical

# Set the path to your dataset
dataset_path = r'E:\Downloads\lung_cls3'

# %%
#cross validation code
# Data preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# Set the path to your dataset
dataset_path = r'E:\Downloads\lung_cls3'

# Data preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# Load data using the generator
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

# Initialize KFold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

# Initialize lists to store results from each fold
accuracies = []

# Define the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(3, activation='softmax'))  # Adjust the output size based on your classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Loop through each fold
for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    print(f"Fold {fold + 1}/{n_splits}")
    
    # Set up new data generators for this fold
    train_generator_fold = train_datagen.flow_from_directory(
        dataset_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='training',
        shuffle=False
    )

    val_generator_fold = train_datagen.flow_from_directory(
        dataset_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation',
        shuffle=False
    )

    # Train the model with this fold's data
    history = model.fit(
        train_generator_fold,
        epochs=1,
        validation_data=val_generator_fold,
        steps_per_epoch=len(train_generator_fold),
        validation_steps=len(val_generator_fold)
    )

    # Evaluate the model on the test set for this fold
    test_generator_fold = train_datagen.flow_from_directory(
        dataset_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=False
    )
    test_accuracy = model.evaluate(test_generator_fold)[1]
    accuracies.append(test_accuracy)

# Calculate the mean and standard deviation of accuracies
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

# Print the mean and standard deviation of accuracies
print(f"Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}")
# Out:
# Found 5523 images belonging to 3 classes.
# Fold 1/5
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# 173/173 [==============================] - 277s 2s/step - loss: 1.4416 - accuracy: 0.4326 - val_loss: 1.1035 - val_accuracy: 0.3988
# Found 6902 images belonging to 3 classes.
# 216/216 [==============================] - 478s 2s/step - loss: 0.9996 - accuracy: 0.4757
# Fold 2/5
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# 173/173 [==============================] - 435s 2s/step - loss: 0.8746 - accuracy: 0.6207 - val_loss: 0.9630 - val_accuracy: 0.5489
# Found 6902 images belonging to 3 classes.
# 216/216 [==============================] - 251s 1s/step - loss: 0.9110 - accuracy: 0.5895
# Fold 3/5
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# 173/173 [==============================] - 492s 3s/step - loss: 0.8314 - accuracy: 0.6315 - val_loss: 1.0853 - val_accuracy: 0.5780
# Found 6902 images belonging to 3 classes.
# 216/216 [==============================] - 370s 2s/step - loss: 0.7551 - accuracy: 0.6840
# Fold 4/5
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# 173/173 [==============================] - 409s 2s/step - loss: 0.7297 - accuracy: 0.6775 - val_loss: 1.5201 - val_accuracy: 0.5482
# Found 6902 images belonging to 3 classes.
# 216/216 [==============================] - 268s 1s/step - loss: 0.8106 - accuracy: 0.6834
# Fold 5/5
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# 173/173 [==============================] - 349s 2s/step - loss: 0.6155 - accuracy: 0.7391 - val_loss: 1.2344 - val_accuracy: 0.6374
# Found 6902 images belonging to 3 classes.
# 216/216 [==============================] - 226s 1s/step - loss: 0.6389 - accuracy: 0.7819
# Mean Accuracy: 0.6429 ± 0.1034

# %%
# Build the CNN model
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))  # Adjust the output size based on your classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with steps_per_epoch set to 100
epochs = 100
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)

# Evaluate the model
test_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Calculate accuracy
test_accuracy = model.evaluate(test_generator)[1]
print("Test Accuracy:", test_accuracy)

# Save the model
model.save('cnn_model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 5523 images belonging to 3 classes.
# Found 1379 images belonging to 3 classes.
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 173/173 [==============================] - 506s 3s/step - loss: 0.6590 - accuracy: 0.7049 - val_loss: 1.2952 - val_accuracy: 0.6679
# Epoch 2/100
# 173/173 [==============================] - 347s 2s/step - loss: 0.4131 - accuracy: 0.8323 - val_loss: 1.9552 - val_accuracy: 0.6983
# Epoch 3/100
# 173/173 [==============================] - 328s 2s/step - loss: 0.3233 - accuracy: 0.8767 - val_loss: 2.0041 - val_accuracy: 0.6882
# Epoch 4/100
# 173/173 [==============================] - 321s 2s/step - loss: 0.2796 - accuracy: 0.8885 - val_loss: 1.5746 - val_accuracy: 0.7469
# Epoch 5/100
# 173/173 [==============================] - 318s 2s/step - loss: 0.2589 - accuracy: 0.9051 - val_loss: 1.5761 - val_accuracy: 0.7302
# Epoch 6/100
# 173/173 [==============================] - 333s 2s/step - loss: 0.2192 - accuracy: 0.9171 - val_loss: 2.2025 - val_accuracy: 0.7476
# Epoch 7/100
# 173/173 [==============================] - 354s 2s/step - loss: 0.1937 - accuracy: 0.9263 - val_loss: 1.5388 - val_accuracy: 0.7607
# Epoch 8/100
# 173/173 [==============================] - 323s 2s/step - loss: 0.1760 - accuracy: 0.9368 - val_loss: 1.6776 - val_accuracy: 0.7679
# Epoch 9/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.1710 - accuracy: 0.9393 - val_loss: 1.9771 - val_accuracy: 0.7984
# Epoch 10/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.1487 - accuracy: 0.9479 - val_loss: 2.4703 - val_accuracy: 0.7839
# Epoch 11/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.1447 - accuracy: 0.9469 - val_loss: 2.2597 - val_accuracy: 0.7745
# Epoch 12/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.1382 - accuracy: 0.9509 - val_loss: 2.0516 - val_accuracy: 0.7665
# Epoch 13/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.1242 - accuracy: 0.9551 - val_loss: 2.2902 - val_accuracy: 0.7912
# Epoch 14/100
# 173/173 [==============================] - 310s 2s/step - loss: 0.1414 - accuracy: 0.9442 - val_loss: 2.4952 - val_accuracy: 0.7933
# Epoch 15/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.1297 - accuracy: 0.9520 - val_loss: 2.5170 - val_accuracy: 0.7883
# Epoch 16/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.1094 - accuracy: 0.9580 - val_loss: 2.0757 - val_accuracy: 0.8100
# Epoch 17/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.0988 - accuracy: 0.9641 - val_loss: 2.4730 - val_accuracy: 0.7868
# Epoch 18/100
# 173/173 [==============================] - 322s 2s/step - loss: 0.0985 - accuracy: 0.9658 - val_loss: 2.3147 - val_accuracy: 0.8049
# Epoch 19/100
# 173/173 [==============================] - 334s 2s/step - loss: 0.0979 - accuracy: 0.9651 - val_loss: 2.1668 - val_accuracy: 0.8035
# Epoch 20/100
# 173/173 [==============================] - 319s 2s/step - loss: 0.0982 - accuracy: 0.9629 - val_loss: 1.9977 - val_accuracy: 0.8093
# Epoch 21/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0869 - accuracy: 0.9681 - val_loss: 2.7218 - val_accuracy: 0.8180
# Epoch 22/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0757 - accuracy: 0.9743 - val_loss: 2.5141 - val_accuracy: 0.8194
# Epoch 23/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0736 - accuracy: 0.9725 - val_loss: 2.7036 - val_accuracy: 0.8107
# Epoch 24/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0857 - accuracy: 0.9708 - val_loss: 2.6126 - val_accuracy: 0.8151
# Epoch 25/100
# 173/173 [==============================] - 308s 2s/step - loss: 0.0947 - accuracy: 0.9678 - val_loss: 3.0045 - val_accuracy: 0.8057
# Epoch 26/100
# 173/173 [==============================] - 310s 2s/step - loss: 0.0729 - accuracy: 0.9736 - val_loss: 2.8349 - val_accuracy: 0.7984
# Epoch 27/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0676 - accuracy: 0.9772 - val_loss: 3.7460 - val_accuracy: 0.7890
# Epoch 28/100
# 173/173 [==============================] - 310s 2s/step - loss: 0.0650 - accuracy: 0.9763 - val_loss: 2.5194 - val_accuracy: 0.8209
# Epoch 29/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0611 - accuracy: 0.9785 - val_loss: 3.1994 - val_accuracy: 0.8144
# Epoch 30/100
# 173/173 [==============================] - 326s 2s/step - loss: 0.0694 - accuracy: 0.9736 - val_loss: 2.5837 - val_accuracy: 0.8057
# Epoch 31/100
# 173/173 [==============================] - 341s 2s/step - loss: 0.0701 - accuracy: 0.9765 - val_loss: 3.0644 - val_accuracy: 0.8209
# Epoch 32/100
# 173/173 [==============================] - 320s 2s/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 2.7736 - val_accuracy: 0.8216
# Epoch 33/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0604 - accuracy: 0.9786 - val_loss: 3.4544 - val_accuracy: 0.8165
# Epoch 34/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0573 - accuracy: 0.9803 - val_loss: 3.5532 - val_accuracy: 0.8144
# Epoch 35/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.0530 - accuracy: 0.9835 - val_loss: 3.3324 - val_accuracy: 0.8281
# Epoch 36/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 3.3074 - val_accuracy: 0.8245
# Epoch 37/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.0535 - accuracy: 0.9814 - val_loss: 4.0605 - val_accuracy: 0.8347
# Epoch 38/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.0526 - accuracy: 0.9801 - val_loss: 2.6992 - val_accuracy: 0.8260
# Epoch 39/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0429 - accuracy: 0.9873 - val_loss: 3.7725 - val_accuracy: 0.8216
# Epoch 40/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0488 - accuracy: 0.9824 - val_loss: 3.3123 - val_accuracy: 0.8289
# Epoch 41/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.0553 - accuracy: 0.9799 - val_loss: 4.5151 - val_accuracy: 0.8274
# Epoch 42/100
# 173/173 [==============================] - 331s 2s/step - loss: 0.0479 - accuracy: 0.9824 - val_loss: 4.0488 - val_accuracy: 0.8151
# Epoch 43/100
# 173/173 [==============================] - 342s 2s/step - loss: 0.0448 - accuracy: 0.9835 - val_loss: 4.3982 - val_accuracy: 0.8223
# Epoch 44/100
# 173/173 [==============================] - 325s 2s/step - loss: 0.0577 - accuracy: 0.9786 - val_loss: 4.1565 - val_accuracy: 0.8136
# Epoch 45/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.0398 - accuracy: 0.9846 - val_loss: 4.2586 - val_accuracy: 0.8260
# Epoch 46/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0387 - accuracy: 0.9852 - val_loss: 4.4691 - val_accuracy: 0.8115
# Epoch 47/100
# 173/173 [==============================] - 315s 2s/step - loss: 0.0435 - accuracy: 0.9839 - val_loss: 3.5348 - val_accuracy: 0.8281
# Epoch 48/100
# 173/173 [==============================] - 315s 2s/step - loss: 0.0489 - accuracy: 0.9828 - val_loss: 4.1879 - val_accuracy: 0.8086
# Epoch 49/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0307 - accuracy: 0.9888 - val_loss: 3.5337 - val_accuracy: 0.8223
# Epoch 50/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0311 - accuracy: 0.9888 - val_loss: 4.1141 - val_accuracy: 0.8289
# Epoch 51/100
# 173/173 [==============================] - 315s 2s/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 4.0334 - val_accuracy: 0.8318
# Epoch 52/100
# 173/173 [==============================] - 315s 2s/step - loss: 0.0350 - accuracy: 0.9862 - val_loss: 3.8771 - val_accuracy: 0.8368
# Epoch 53/100
# 173/173 [==============================] - 319s 2s/step - loss: 0.0238 - accuracy: 0.9917 - val_loss: 4.6822 - val_accuracy: 0.8318
# Epoch 54/100
# 173/173 [==============================] - 338s 2s/step - loss: 0.0343 - accuracy: 0.9871 - val_loss: 4.0687 - val_accuracy: 0.8180
# Epoch 55/100
# 173/173 [==============================] - 348s 2s/step - loss: 0.0350 - accuracy: 0.9870 - val_loss: 3.8009 - val_accuracy: 0.8310
# Epoch 56/100
# 173/173 [==============================] - 332s 2s/step - loss: 0.0300 - accuracy: 0.9902 - val_loss: 4.1805 - val_accuracy: 0.8129
# Epoch 57/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0385 - accuracy: 0.9861 - val_loss: 4.3369 - val_accuracy: 0.8310
# Epoch 58/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0319 - accuracy: 0.9879 - val_loss: 4.2272 - val_accuracy: 0.8231
# Epoch 59/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0399 - accuracy: 0.9846 - val_loss: 3.6623 - val_accuracy: 0.8296
# Epoch 60/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 4.3253 - val_accuracy: 0.8267
# Epoch 61/100
# 173/173 [==============================] - 323s 2s/step - loss: 0.0247 - accuracy: 0.9908 - val_loss: 4.6875 - val_accuracy: 0.8274
# Epoch 62/100
# 173/173 [==============================] - 310s 2s/step - loss: 0.0365 - accuracy: 0.9873 - val_loss: 5.4220 - val_accuracy: 0.8245
# Epoch 63/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.0412 - accuracy: 0.9868 - val_loss: 3.0202 - val_accuracy: 0.8267
# Epoch 64/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0238 - accuracy: 0.9904 - val_loss: 3.2967 - val_accuracy: 0.8267
# Epoch 65/100
# 173/173 [==============================] - 318s 2s/step - loss: 0.0272 - accuracy: 0.9911 - val_loss: 3.7464 - val_accuracy: 0.8310
# Epoch 66/100
# 173/173 [==============================] - 332s 2s/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 3.6194 - val_accuracy: 0.8252
# Epoch 67/100
# 173/173 [==============================] - 336s 2s/step - loss: 0.0377 - accuracy: 0.9877 - val_loss: 3.5692 - val_accuracy: 0.8274
# Epoch 68/100
# 173/173 [==============================] - 328s 2s/step - loss: 0.0247 - accuracy: 0.9908 - val_loss: 3.2752 - val_accuracy: 0.8325
# Epoch 69/100
# 173/173 [==============================] - 312s 2s/step - loss: 0.0346 - accuracy: 0.9895 - val_loss: 3.8145 - val_accuracy: 0.8368
# Epoch 70/100
# 173/173 [==============================] - 309s 2s/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 4.4584 - val_accuracy: 0.8252
# Epoch 71/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 3.9379 - val_accuracy: 0.8390
# Epoch 72/100
# 173/173 [==============================] - 309s 2s/step - loss: 0.0339 - accuracy: 0.9879 - val_loss: 3.5938 - val_accuracy: 0.8151
# Epoch 73/100
# 173/173 [==============================] - 311s 2s/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 4.0273 - val_accuracy: 0.8281
# Epoch 74/100
# 173/173 [==============================] - 307s 2s/step - loss: 0.0213 - accuracy: 0.9919 - val_loss: 4.9771 - val_accuracy: 0.8281
# Epoch 75/100
# 173/173 [==============================] - 306s 2s/step - loss: 0.0319 - accuracy: 0.9893 - val_loss: 3.7767 - val_accuracy: 0.8289
# Epoch 76/100
# 173/173 [==============================] - 310s 2s/step - loss: 0.0251 - accuracy: 0.9908 - val_loss: 3.9989 - val_accuracy: 0.8332
# Epoch 77/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 4.8395 - val_accuracy: 0.8238
# Epoch 78/100
# 173/173 [==============================] - 344s 2s/step - loss: 0.0282 - accuracy: 0.9893 - val_loss: 5.9398 - val_accuracy: 0.8129
# Epoch 79/100
# 173/173 [==============================] - 340s 2s/step - loss: 0.0196 - accuracy: 0.9922 - val_loss: 4.2004 - val_accuracy: 0.8267
# Epoch 80/100
# 173/173 [==============================] - 321s 2s/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 4.2565 - val_accuracy: 0.8368
# Epoch 81/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0162 - accuracy: 0.9938 - val_loss: 4.4325 - val_accuracy: 0.8252
# Epoch 82/100
# 173/173 [==============================] - 308s 2s/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 5.4357 - val_accuracy: 0.8252
# Epoch 83/100
# 173/173 [==============================] - 314s 2s/step - loss: 0.0219 - accuracy: 0.9922 - val_loss: 4.0521 - val_accuracy: 0.8318
# Epoch 84/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0407 - accuracy: 0.9855 - val_loss: 3.0795 - val_accuracy: 0.8296
# Epoch 85/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 4.4516 - val_accuracy: 0.8173
# Epoch 86/100
# 173/173 [==============================] - 318s 2s/step - loss: 0.0197 - accuracy: 0.9924 - val_loss: 4.7608 - val_accuracy: 0.8339
# Epoch 87/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 3.7774 - val_accuracy: 0.8296
# Epoch 88/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 4.6200 - val_accuracy: 0.8274
# Epoch 89/100
# 173/173 [==============================] - 323s 2s/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 4.3210 - val_accuracy: 0.8289
# Epoch 90/100
# 173/173 [==============================] - 338s 2s/step - loss: 0.0214 - accuracy: 0.9922 - val_loss: 3.6112 - val_accuracy: 0.8274
# Epoch 91/100
# 173/173 [==============================] - 332s 2s/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 3.7573 - val_accuracy: 0.8267
# Epoch 92/100
# 173/173 [==============================] - 326s 2s/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 3.9486 - val_accuracy: 0.8412
# Epoch 93/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 4.7117 - val_accuracy: 0.8354
# Epoch 94/100
# 173/173 [==============================] - 322s 2s/step - loss: 0.0535 - accuracy: 0.9832 - val_loss: 4.7014 - val_accuracy: 0.8245
# Epoch 95/100
# 173/173 [==============================] - 317s 2s/step - loss: 0.0221 - accuracy: 0.9924 - val_loss: 5.4127 - val_accuracy: 0.8310
# Epoch 96/100
# 173/173 [==============================] - 319s 2s/step - loss: 0.0233 - accuracy: 0.9913 - val_loss: 5.6011 - val_accuracy: 0.8173
# Epoch 97/100
# 173/173 [==============================] - 316s 2s/step - loss: 0.0301 - accuracy: 0.9899 - val_loss: 4.5619 - val_accuracy: 0.8216
# Epoch 98/100
# 173/173 [==============================] - 318s 2s/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 4.1548 - val_accuracy: 0.8296
# Epoch 99/100
# 173/173 [==============================] - 313s 2s/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 5.4697 - val_accuracy: 0.8173
# Epoch 100/100
# 173/173 [==============================] - 320s 2s/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 4.2166 - val_accuracy: 0.8376
# Found 1379 images belonging to 3 classes.
# 44/44 [==============================] - 29s 638ms/step - loss: 4.2234 - accuracy: 0.8390
# Test Accuracy: 0.8390137553215027
# C:\Users\Omi Siddhu\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# ... (previous code)

# Evaluate the model
test_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Get true labels
y_true = test_generator.classes

# Get predicted probabilities
y_pred_probabilities = model.predict(test_generator)

# Get predicted labels
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Calculate accuracy
test_accuracy = model.evaluate(test_generator)[1]
print("Test Accuracy:", test_accuracy)

# Print Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_true, y_pred))

# Print Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred))

# Print AUC Score
print("\nAUC Score:")
print(roc_auc_score(to_categorical(y_true), y_pred_probabilities))
# Out:
# Found 1379 images belonging to 3 classes.
# 44/44 [==============================] - 35s 772ms/step
# 44/44 [==============================] - 29s 645ms/step - loss: 4.1644 - accuracy: 0.8376
# Test Accuracy: 0.8375634551048279
# Confusion Matrix:
# [[437  15   3]
#  [ 20 442   0]
#  [  9 177 276]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       455
#            1       0.70      0.96      0.81       462
#            2       0.99      0.60      0.74       462
#
#     accuracy                           0.84      1379
#    macro avg       0.87      0.84      0.83      1379
# weighted avg       0.87      0.84      0.83      1379
#
#
# AUC Score:
# 0.8966987816497086
